# %%
import numpy as np
import matplotlib.image as mpimg
from helpers import BirdsEye, plot_six_images, show_dotted_image, compare_birdseye

# %%
# (x, y) lowerleft, upperleft, upperright, lowerright
source_points = [(0, 43), (130, 15), (190, 15), (320, 43)]
dest_points = [(130, 50), (130, 10), (190, 10), (190, 50)]
birds_eye = BirdsEye(source_points, dest_points)

# %%
test_img0 = mpimg.imread("./samples/tests-perspectives-images/img0.jpg")
test_img1 = mpimg.imread("./samples/tests-perspectives-images/img1.jpg")
test_img2 = mpimg.imread("./samples/tests-perspectives-images/img2.jpg")
test_img3 = mpimg.imread("./samples/tests-perspectives-images/img3.jpg")
test_img4 = mpimg.imread("./samples/tests-perspectives-images/img4.jpg")
test_img5 = mpimg.imread("./samples/tests-perspectives-images/img5.jpg")

YSTART, YSTOP = 100, 155
strip0 = test_img0[YSTART:YSTOP, :, :]
strip1 = test_img1[YSTART:YSTOP, :, :]
strip2 = test_img2[YSTART:YSTOP, :, :]
strip3 = test_img3[YSTART:YSTOP, :, :]
strip4 = test_img4[YSTART:YSTOP, :, :]
strip5 = test_img5[YSTART:YSTOP, :, :]

plot_six_images(test_img0, test_img1, test_img2, test_img3, test_img4, test_img5, 17, 8)
plot_six_images(strip0, strip1, strip2, strip3, strip4, strip5, 17, 3)

compare_birdseye(birds_eye, strip0)
compare_birdseye(birds_eye, strip1)
compare_birdseye(birds_eye, strip3)
compare_birdseye(birds_eye, strip4)
compare_birdseye(birds_eye, strip5)

# %%
test_img0 = mpimg.imread("./samples/tests-perspectives-images/i1.jpg")
test_img1 = mpimg.imread("./samples/tests-perspectives-images/i2.jpg")
test_img2 = mpimg.imread("./samples/tests-perspectives-images/i3.jpg")
test_img3 = mpimg.imread("./samples/tests-perspectives-images/i4.jpg")
test_img4 = mpimg.imread("./samples/tests-perspectives-images/i5.jpg")
test_img5 = mpimg.imread("./samples/tests-perspectives-images/i6.jpg")

YSTART, YSTOP = 100, 155
strip0 = test_img0[YSTART:YSTOP, :, :]
strip1 = test_img1[YSTART:YSTOP, :, :]
strip2 = test_img2[YSTART:YSTOP, :, :]
strip3 = test_img3[YSTART:YSTOP, :, :]
strip4 = test_img4[YSTART:YSTOP, :, :]
strip5 = test_img5[YSTART:YSTOP, :, :]

plot_six_images(test_img0, test_img1, test_img2, test_img3, test_img4, test_img5, 17, 8)
plot_six_images(strip0, strip1, strip2, strip3, strip4, strip5, 17, 3)

compare_birdseye(birds_eye, strip0)
compare_birdseye(birds_eye, strip1)
compare_birdseye(birds_eye, strip3)
compare_birdseye(birds_eye, strip4)
compare_birdseye(birds_eye, strip5)

# %%
test_img0 = mpimg.imread("./samples/tests-perspectives-images/i7.jpg")
test_img1 = mpimg.imread("./samples/tests-perspectives-images/i8.jpg")
test_img2 = mpimg.imread("./samples/tests-perspectives-images/i9.jpg")
test_img3 = mpimg.imread("./samples/tests-perspectives-images/i10.jpg")
test_img4 = mpimg.imread("./samples/tests-perspectives-images/i11.jpg")
test_img5 = mpimg.imread("./samples/tests-perspectives-images/i12.jpg")

YSTART, YSTOP = 100, 155
strip0 = test_img0[YSTART:YSTOP, :, :]
strip1 = test_img1[YSTART:YSTOP, :, :]
strip2 = test_img2[YSTART:YSTOP, :, :]
strip3 = test_img3[YSTART:YSTOP, :, :]
strip4 = test_img4[YSTART:YSTOP, :, :]
strip5 = test_img5[YSTART:YSTOP, :, :]

plot_six_images(test_img0, test_img1, test_img2, test_img3, test_img4, test_img5, 17, 8)
plot_six_images(strip0, strip1, strip2, strip3, strip4, strip5, 17, 3)

compare_birdseye(birds_eye, strip0)
compare_birdseye(birds_eye, strip1)
compare_birdseye(birds_eye, strip3)
compare_birdseye(birds_eye, strip4)
compare_birdseye(birds_eye, strip5)
